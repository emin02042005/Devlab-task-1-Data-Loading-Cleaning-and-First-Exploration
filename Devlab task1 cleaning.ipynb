# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("sales_data_sample.xlsx")

# %%
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#                 ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   object
#  6   STATUS            2823 non-null   object
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int64
#  10  PRODUCTLINE       2823 non-null   object
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   object
#  13  CUSTOMERNAME      2823 non-null   object
#  14  PHONE             2823 non-null   object
#  15  ADDRESSLINE1      2823 non-null   object
# ...

# %%
df.describe()
# Out:
#         ORDERNUMBER  QUANTITYORDERED     PRICEEACH  ORDERLINENUMBER  \
# count   2823.000000      2823.000000   2823.000000      2823.000000
# mean   10258.725115        35.092809    149.157680         6.466171
# std       92.085478         9.741443   1737.227587         4.225841
# min    10100.000000         6.000000     26.880000         1.000000
# 25%    10180.000000        27.000000     69.120000         3.000000
# 50%    10262.000000        35.000000     95.880000         6.000000
# 75%    10333.500000        43.000000    100.000000         9.000000
# max    10425.000000        97.000000  46387.000000        18.000000
#
#               SALES       QTR_ID     MONTH_ID     YEAR_ID         MSRP
# count   2823.000000  2823.000000  2823.000000  2823.00000  2823.000000
# mean    3553.889072     2.717676     7.092455  2003.81509   100.715551
# std     1841.865106     1.203878     3.656633     0.69967    40.187912
# min      482.130000     1.000000     1.000000  2003.00000    33.000000
# ...

# %%
# Load sales_data_sample.csv with pandas, display shape and column names
np.shape(df)
# Out:
# (2823, 25)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   object
#  6   STATUS            2823 non-null   object
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int64
#  10  PRODUCTLINE       2823 non-null   object
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   object
#  13  CUSTOMERNAME      2823 non-null   object
#  14  PHONE             2823 non-null   object
#  15  ADDRESSLINE1      2823 non-null   object
# ...

# %%
# Check data types; convert ORDERDATE column to datetime
df.dtypes
# Out:
# ORDERNUMBER           int64
# QUANTITYORDERED       int64
# PRICEEACH           float64
# ORDERLINENUMBER       int64
# SALES               float64
# ORDERDATE            object
# STATUS               object
# QTR_ID                int64
# MONTH_ID              int64
# YEAR_ID               int64
# PRODUCTLINE          object
# MSRP                  int64
# PRODUCTCODE          object
# CUSTOMERNAME         object
# PHONE                object
# ADDRESSLINE1         object
# ADDRESSLINE2         object
# CITY                 object
# STATE                object
# POSTALCODE           object
# COUNTRY              object
# TERRITORY            object
# CONTACTLASTNAME      object
# CONTACTFIRSTNAME     object
# DEALSIZE             object
# dtype: object

# %%
df['ORDERDATE'].dtype
# Out:
# dtype('O')

# %%
df["ORDERDATE"] = pd.to_datetime(df["ORDERDATE"])
df['ORDERDATE'].dtype
# Out:
# dtype('<M8[ns]')

# %%
#Identify and handle missing values (fill with "Unknown" or appropriate value)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   datetime64[ns]
#  6   STATUS            2823 non-null   object
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int64
#  10  PRODUCTLINE       2823 non-null   object
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   object
#  13  CUSTOMERNAME      2823 non-null   object
#  14  PHONE             2823 non-null   object
#  15  ADDRESSLINE1      2823 non-null   object
# ...

# %%
df["STATE"].isnull().sum()
# Out:
# np.int64(1486)

# %%
df['STATE']
# Out:
# 0        NY
# 1       NaN
# 2       NaN
# 3        CA
# 4        CA
#        ...
# 2818    NaN
# 2819    NaN
# 2820    NaN
# 2821    NaN
# 2822     MA
# Name: STATE, Length: 2823, dtype: object

# %%
df['STATE'] = df['STATE'].fillna("Unknown")

# %%
df['STATE'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['TERRITORY'].value_counts()
# Out:
# TERRITORY
# EMEA     1407
# APAC      221
# Japan     121
# Name: count, dtype: int64

# %%
df['TERRITORY'] = df['TERRITORY'].fillna("Unknown1")

# %%
df['TERRITORY'].isnull().sum()
# Out:
# np.int64(0)

# %%
df = df.drop(columns=['ADDRESSLINE2'])

# %%
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#       ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...             PHONE  \
# ...

# %%
# Check and report duplicates
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Generate summary statistics with df.describe() for numeric columns
df.describe()
# Out:
#         ORDERNUMBER  QUANTITYORDERED     PRICEEACH  ORDERLINENUMBER  \
# count   2823.000000      2823.000000   2823.000000      2823.000000
# mean   10258.725115        35.092809    149.157680         6.466171
# min    10100.000000         6.000000     26.880000         1.000000
# 25%    10180.000000        27.000000     69.120000         3.000000
# 50%    10262.000000        35.000000     95.880000         6.000000
# 75%    10333.500000        43.000000    100.000000         9.000000
# max    10425.000000        97.000000  46387.000000        18.000000
# std       92.085478         9.741443   1737.227587         4.225841
#
#               SALES                      ORDERDATE       QTR_ID     MONTH_ID  \
# count   2823.000000                           2823  2823.000000  2823.000000
# mean    3553.889072  2004-04-25 07:13:04.272050944     2.717676     7.092455
# min      482.130000            2003-01-04 00:00:00     1.000000     1.000000
# ...

# %%
numeric_df = df.select_dtypes(include=['float64', 'int64'])

corr_matrix = numeric_df.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")

plt.title('Satış Məlumatlarının Korrelyasiya Heatmap-i')
plt.show()

# %%
df["PRICEEACH"]
# Out:
# 0        95.70
# 1        81.35
# 2        94.74
# 3        83.26
# 4       100.00
#          ...
# 2818    100.00
# 2819    100.00
# 2820    100.00
# 2821     62.24
# 2822     65.52
# Name: PRICEEACH, Length: 2823, dtype: float64

# %%
bahali_mehsul = df[df['PRICEEACH'] == df['PRICEEACH'].max()]
bahali_mehsul
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 1722        10175               37    46387.0                2  1151.44
#
#       ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...           PHONE  \
# 1722 2003-06-11  Shipped       4        11     2003  ...  (171) 555-0297
#
#         ADDRESSLINE1    CITY    STATE POSTALCODE COUNTRY TERRITORY  \
# 1722  35 King George  London  Unknown    WX3 6FW      UK      EMEA
#
#      CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 1722           Brown              Ann    Small
#
# [1 rows x 24 columns]

# %%
df['PRODUCTLINE'].value_counts()
# Out:
# PRODUCTLINE
# Classic Cars        967
# Vintage Cars        607
# Motorcycles         331
# Planes              306
# Trucks and Buses    301
# Ships               234
# Trains               77
# Name: count, dtype: int64

# %%
# Use value_counts() on STATUS, YEAR_ID and PRODUCTLINE columns
df['STATUS'].value_counts()
# Out:
# STATUS
# Shipped       2617
# Cancelled       60
# Resolved        47
# On Hold         44
# In Process      41
# Disputed        14
# Name: count, dtype: int64

# %%
df['YEAR_ID'].value_counts()
# Out:
# YEAR_ID
# 2004    1345
# 2003    1000
# 2005     478
# Name: count, dtype: int64

# %%
df['PRODUCTLINE'].value_counts()
# Out:
# PRODUCTLINE
# Classic Cars        967
# Vintage Cars        607
# Motorcycles         331
# Planes              306
# Trucks and Buses    301
# Ships               234
# Trains               77
# Name: count, dtype: int64

# %%
product_counts = df['PRODUCTLINE'].value_counts()

plt.figure(figsize=(12, 6))
product_counts.plot(kind='bar', color='salmon', edgecolor='black')

plt.title('Məhsul Kateqoriyalarına Görə Satış Sayı', fontsize=15)
plt.xlabel('Məhsul Xətti (Product Line)', fontsize=12)
plt.ylabel('Sifarişlərin Sayı', fontsize=12)

plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout() 
plt.show()

# %%
sales2005 = df[df['YEAR_ID'] == 2005]
sales2005
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 22          10375               21      34.91               12   733.11
# 23          10388               42      76.36                4  3207.12
# 24          10403               24     100.00                7  2434.56
# 25          10417               66     100.00                2  7516.08
# 49          10369               41     100.00                2  4514.92
# ...           ...              ...        ...              ...      ...
# 2796        10415               42      57.61                3  2419.62
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#       ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...           PHONE  \
# ...

# %%
sales2005.describe()
# Out:
#         ORDERNUMBER  QUANTITYORDERED   PRICEEACH  ORDERLINENUMBER  \
# count    478.000000       478.000000  478.000000       478.000000
# mean   10392.297071        36.884937   83.445251         5.972803
# min    10362.000000         6.000000   26.880000         1.000000
# 25%    10375.250000        28.000000   67.252500         3.000000
# 50%    10390.000000        36.000000   95.190000         5.000000
# 75%    10410.500000        45.000000  100.000000         9.000000
# max    10425.000000        97.000000  100.000000        18.000000
# std       18.456352        12.527929   20.354340         4.029932
#
#               SALES                      ORDERDATE      QTR_ID    MONTH_ID  \
# count    478.000000                            478  478.000000  478.000000
# mean    3747.880146  2005-04-20 00:21:05.271966464    1.368201    3.002092
# min      482.130000            2005-01-03 00:00:00    1.000000    1.000000
# ...

# %%
sales2005['PRODUCTLINE'].value_counts()
# Out:
# PRODUCTLINE
# Classic Cars        159
# Vintage Cars        102
# Planes               60
# Motorcycles          58
# Trucks and Buses     49
# Ships                38
# Trains               12
# Name: count, dtype: int64

# %%
# Iller kecdikce classic cars satisi azaldigina gore sirketin satis faizleri azalibbb

# %%
# Write 3-4 business insights based on the data
df['PRODUCTLINE'].value_counts()
#Sirketin esas gelir menbeyi classic carsdir
# Out:
# PRODUCTLINE
# Classic Cars        967
# Vintage Cars        607
# Motorcycles         331
# Planes              306
# Trucks and Buses    301
# Ships               234
# Trains               77
# Name: count, dtype: int64

# %%
df['YEAR_ID'].value_counts()
#Gorunduyu kimi sirket pik heddini 2004-cu ilde yasayibb sonraki illerde satis faizinin azalmasi sebebi 2 cur ola biler 
# ya modern telebatlara yonelib insanlar yadaki bazarda reqabet artib
# Out:
# YEAR_ID
# 2004    1345
# 2003    1000
# 2005     478
# Name: count, dtype: int64

# %%
annual_counts = df['YEAR_ID'].value_counts().sort_index()

plt.figure(figsize=(10, 6))
plt.plot(annual_counts.index, annual_counts.values, marker='s', linestyle='--', color='green', linewidth=2)

plt.title('İllərə görə Sifariş Sayı (Transaction Count)', fontsize=14)
plt.xlabel('İl', fontsize=12)
plt.ylabel('Sifarişlərin Sayı', fontsize=12)
plt.xticks(annual_counts.index)
plt.grid(True, alpha=0.3)

plt.show()

# %%
df['STATUS'].value_counts()
# Out:
# STATUS
# Shipped       2617
# Cancelled       60
# Resolved        47
# On Hold         44
# In Process      41
# Disputed        14
# Name: count, dtype: int64
